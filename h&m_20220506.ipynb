# %% [markdown]
# <a href="https://colab.research.google.com/github/jellyontherock/AI/blob/master/h%26m_20220506.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''

1. SQL로 데이터 전처리 (본 파일이 3GB 이상)

select article_id, count(article_id)
from transactions_train_csv ttc 
group by article_id; # test.csv로 저장

select *
from test
	full outer join articles a 
	on test.article_id = a.article_id; #test_2.csv로 저장
'''

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/drive/MyDrive/머신러닝/H&M 구매 분석/test_2.csv')
df = pd.DataFrame(df)
df.head()
# Out:
#     article_id    count  article_id.1  product_code                 prod_name  \
# 0  108775044.0   7250.0     108775044        108775                 Strap top
# 1  110065002.0    539.0     110065002        110065         OP T-shirt (Idro)
# 2  110065011.0   1090.0     110065011        110065         OP T-shirt (Idro)
# 3  111565003.0     46.0     111565003        111565       20 den 1p Stockings
# 4  111593001.0  13888.0     111593001        111593  Support 40 den 1p Tights
#
#    product_type_no product_type_name  product_group_name  \
# 0              253          Vest top  Garment Upper body
# 1              306               Bra           Underwear
# 2              306               Bra           Underwear
# 3              302             Socks      Socks & Tights
# 4              304  Underwear Tights      Socks & Tights
#
#    graphical_appearance_no graphical_appearance_name  ...  department_no  \
# 0                  1010016                     Solid  ...           1676
# ...

# %%
df.columns
# Out:
# Index(['article_id', 'count', 'article_id.1', 'product_code', 'prod_name',
#        'product_type_no', 'product_type_name', 'product_group_name',
#        'graphical_appearance_no', 'graphical_appearance_name',
#        'colour_group_code', 'colour_group_name', 'perceived_colour_value_id',
#        'perceived_colour_value_name', 'perceived_colour_master_id',
#        'perceived_colour_master_name', 'department_no', 'department_name',
#        'index_code', 'index_name', 'index_group_no', 'index_group_name',
#        'section_no', 'section_name', 'garment_group_no', 'garment_group_name'],
#       dtype='object')

# %%
df = df[['article_id', 'count', 'prod_name', 'product_type_name', 'product_group_name', 'index_name', 'index_group_name', 'section_name','perceived_colour_master_name']]
df.head(1)
# Out:
#     article_id   count  prod_name product_type_name  product_group_name  \
# 0  108775044.0  7250.0  Strap top          Vest top  Garment Upper body
#
#    index_name index_group_name            section_name  \
# 0  Ladieswear       Ladieswear  Womens Everyday Basics
#
#   perceived_colour_master_name
# 0                        White

# %%
df = df.sort_values('count',ascending=False)
df = df[:100]

# %%
df
# Out:
#         article_id    count                 prod_name product_type_name  \
# 79622  706016001.0  50287.0  Jade HW Skinny Denim TRS          Trousers
# 26892  706016002.0  35043.0  Jade HW Skinny Denim TRS          Trousers
# 53493  372860001.0  31718.0        7p Basic Shaftless             Socks
# 65034  610776002.0  30199.0                 Tilly (1)           T-shirt
# 35081  759871002.0  26329.0                Tilda tank          Vest top
# ...            ...      ...                       ...               ...
# 34133  753737001.0   9723.0         Twenty HW tapered          Trousers
# 88181  762846001.0   9663.0               Lucy blouse             Shirt
# 23085  685813001.0   9579.0          PETAR SWEATSHIRT           Sweater
# 28720  716672001.0   9394.0              Jennifer Top          Vest top
# 11354  599580055.0   9387.0    Timeless Midrise Brief   Swimwear bottom
#
#        product_group_name        index_name index_group_name  \
# ...
